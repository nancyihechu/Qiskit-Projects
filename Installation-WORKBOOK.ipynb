# %%
# !pip install qiskit-ibm-runtime
# Out:
# Collecting qiskit-ibm-runtime
#   Downloading qiskit_ibm_runtime-0.41.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: requests>=2.19 in /home/nigby/miniconda3/envs/QISKIT/lib/python3.13/site-packages (from qiskit-ibm-runtime) (2.32.5)
# Collecting requests-ntlm>=1.1.0 (from qiskit-ibm-runtime)
#   Downloading requests_ntlm-1.3.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.13 in /home/nigby/miniconda3/envs/QISKIT/lib/python3.13/site-packages (from qiskit-ibm-runtime) (2.3.3)
# Requirement already satisfied: urllib3>=1.21.1 in /home/nigby/miniconda3/envs/QISKIT/lib/python3.13/site-packages (from qiskit-ibm-runtime) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/nigby/miniconda3/envs/QISKIT/lib/python3.13/site-packages (from qiskit-ibm-runtime) (2.9.0.post0)
# Collecting ibm-platform-services>=0.22.6 (from qiskit-ibm-runtime)
#   Downloading ibm_platform_services-0.68.2-py3-none-any.whl.metadata (9.0 kB)
# Collecting pydantic>=2.5.0 (from qiskit-ibm-runtime)
#   Downloading pydantic-2.11.9-py3-none-any.whl.metadata (68 kB)
# Requirement already satisfied: qiskit>=1.4.1 in /home/nigby/miniconda3/envs/QISKIT/lib/python3.13/site-packages (from qiskit-ibm-runtime) (2.1.2)
# Requirement already satisfied: packaging in /home/nigby/miniconda3/envs/QISKIT/lib/python3.13/site-packages (from qiskit-ibm-runtime) (25.0)
# Collecting ibm_cloud_sdk_core<4.0.0,>=3.24.2 (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime)
#   Downloading ibm_cloud_sdk_core-3.24.2-py3-none-any.whl.metadata (8.7 kB)
# Collecting PyJWT<3.0.0,>=2.10.1 (from ibm_cloud_sdk_core<4.0.0,>=3.24.2->ibm-platform-services>=0.22.6->qiskit-ibm-runtime)
#   Downloading PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: six>=1.5 in /home/nigby/miniconda3/envs/QISKIT/lib/python3.13/site-packages (from python-dateutil>=2.8.0->qiskit-ibm-runtime) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/nigby/miniconda3/envs/QISKIT/lib/python3.13/site-packages (from requests>=2.19->qiskit-ibm-runtime) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/nigby/miniconda3/envs/QISKIT/lib/python3.13/site-packages (from requests>=2.19->qiskit-ibm-runtime) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nigby/miniconda3/envs/QISKIT/lib/python3.13/site-packages (from requests>=2.19->qiskit-ibm-runtime) (2025.8.3)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.5.0->qiskit-ibm-runtime)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic>=2.5.0->qiskit-ibm-runtime)
#   Downloading pydantic_core-2.33.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/nigby/miniconda3/envs/QISKIT/lib/python3.13/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (4.15.0)
# Collecting typing-inspection>=0.4.0 (from pydantic>=2.5.0->qiskit-ibm-runtime)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: rustworkx>=0.15.0 in /home/nigby/miniconda3/envs/QISKIT/lib/python3.13/site-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (0.17.1)
# Requirement already satisfied: scipy>=1.5 in /home/nigby/miniconda3/envs/QISKIT/lib/python3.13/site-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (1.16.2)
# Requirement already satisfied: dill>=0.3 in /home/nigby/miniconda3/envs/QISKIT/lib/python3.13/site-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (0.4.0)
# Requirement already satisfied: stevedore>=3.0.0 in /home/nigby/miniconda3/envs/QISKIT/lib/python3.13/site-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (5.5.0)
# Collecting cryptography>=1.3 (from requests-ntlm>=1.1.0->qiskit-ibm-runtime)
#   Downloading cryptography-45.0.7-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Collecting pyspnego>=0.4.0 (from requests-ntlm>=1.1.0->qiskit-ibm-runtime)
#   Downloading pyspnego-0.12.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: cffi>=1.14 in /home/nigby/miniconda3/envs/QISKIT/lib/python3.13/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (1.17.1)
# Requirement already satisfied: pycparser in /home/nigby/miniconda3/envs/QISKIT/lib/python3.13/site-packages (from cffi>=1.14->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.22)
# Downloading qiskit_ibm_runtime-0.41.1-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 20.0 MB/s  0:00:00
# Downloading ibm_platform_services-0.68.2-py3-none-any.whl (366 kB)
# Downloading ibm_cloud_sdk_core-3.24.2-py3-none-any.whl (75 kB)
# Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading pydantic-2.11.9-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 49.0 MB/s  0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading requests_ntlm-1.3.0-py3-none-any.whl (6.6 kB)
# Downloading cryptography-45.0.7-cp311-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 55.4 MB/s  0:00:00
# Downloading pyspnego-0.12.0-py3-none-any.whl (130 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, PyJWT, pydantic-core, annotated-types, pydantic, ibm_cloud_sdk_core, cryptography, pyspnego, ibm-platform-services, requests-ntlm, qiskit-ibm-runtime
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [qiskit-ibm-runtime]iskit-ibm-runtime]es]
# Successfully installed PyJWT-2.10.1 annotated-types-0.7.0 cryptography-45.0.7 ibm-platform-services-0.68.2 ibm_cloud_sdk_core-3.24.2 pydantic-2.11.9 pydantic-core-2.33.2 pyspnego-0.12.0 qiskit-ibm-runtime-0.41.1 requests-ntlm-1.3.0 typing-inspection-0.4.1

# %%
import qiskit

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

# %%
service = QiskitRuntimeService(channel="ibm_cloud", instance="crn:v1:bluemix:public:quantum-computing:us-east:a/3fd1683bdb2f4bd7b5a9c16264e9531f:ad7d91c7-83ac-4940-9232-867c319705d5::", token="A739W1bW-U5UuPhvQom6N87S-N5DA3tf2o8YpfAeS_bR")

# %% [markdown]
# ## Homework One

# %%
service.backends()
# Out:
# [<IBMBackend('ibm_kingston')>,
#  <IBMBackend('ibm_pittsburgh')>,
#  <IBMBackend('ibm_brisbane')>,
#  <IBMBackend('ibm_marrakesh')>,
#  <IBMBackend('ibm_torino')>,
#  <IBMBackend('ibm_fez')>]
